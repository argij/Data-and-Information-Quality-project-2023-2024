# %%
from sklearn.datasets import make_regression, make_classification, make_blobs
import matplotlib.pyplot as plt

# DEFAULT PARAMETERS FOR REGRESSION
#X, y = make_dataset_for_regression(n_samples=1000, n_features=3, n_informative=3, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, seed=2023)

def make_dataset_for_regression(n_samples, n_features, n_informative, n_targets, bias, effective_rank, tail_strength, noise, seed, shuffle=True):
    X, y = make_regression(n_samples=n_samples, n_features=n_features, n_informative=n_informative, n_targets=n_targets,
                           bias=bias, effective_rank=effective_rank, tail_strength=tail_strength, noise=noise, shuffle=shuffle, random_state=seed)
    return X, y

# %%
'''
# Scatter plot for regression
# FIrst plot we have all the features together(not very interesting :()
# Second plot we have a plot for every feature

#Extract th column i from a matrix
def column(matrix, i):
    return [row[i] for row in matrix]

n_features = 5
n_informative = 3

X,y = make_dataset_for_regression(200, n_features, n_informative, 1, 0.01, None, 0.5, 0.2, 64)

for n in range(n_features):
  feature_column = column(X, n)
  plt.scatter(feature_column, y)

fig, axs = plt.subplots(n_features)
fig.suptitle('Vertically stacked subplots')

for n in range(n_features):
  feature_column = column(X, n)
  axs[n].scatter(feature_column, y)

'''
